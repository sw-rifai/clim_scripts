# %%
import numpy as np
import xarray as xr

# %%
o = xr.open_dataset("/content/drive/My Drive/work/research/data_general/clim_grid/awap/AWAP/Monthly_data_1911_2019/Monthly_total_precipitation_AWAP_masked_1900_2019.nc")

# %%
o
# Out:
# <xarray.Dataset>
# Dimensions:    (bnds: 2, lat: 691, lon: 886, time: 1431)
# Coordinates:
#   * lon        (lon) float32 112.0 112.05 112.1 112.15 ... 156.15 156.2 156.25
#   * lat        (lat) float32 -44.5 -44.45 -44.4 ... -10.099998 -10.049999 -10.0
#   * time       (time) datetime64[ns] 1900-01-16 ... 2019-03-16
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds  (time, bnds) datetime64[ns] ...
#     pre        (time, lat, lon) float32 ...
# Attributes:
#     CDI:            Climate Data Interface version 1.8.0 (http://mpimet.mpg.d...
#     Conventions:    CF-1.6
#     history:        Thu Aug 15 10:47:34 2019: cdo -L div /srv/ccrc/data04/z35...
#     source:         Australian Bureau of Meteorology
#     creation_date:  Mon Sep  8 14:56:19 EST 2014
#     contact:        William Wang - X.Wang@bom.gov.au
#     title:          Australian Water Availability Project
#     frequency:      mon
# ...
