# %%
import xarray as xr
import numpy as np 
import cartopy.crs as ccrs
import os as os
from matplotlib import pyplot as plt

# %%
os.getcwd()
# Out:
# '/home/sami/srifai@gmail.com/work/research/clim_scripts/python'

# %%
vod = xr.open_dataset("../../data_general/Oz_misc_data/LPDRv2_VODday_monmean_2002_2019.nc")

# %%
vod.vod_day[1].plot()

# %%
ax = plt.axes(projection=ccrs.Orthographic(135, -35))
vod.isel(time=0).plot(ax=ax, transform=ccrs.PlateCarree());
ax.set_global(); ax.coastlines();
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-52f1c80f9f1f> in <module>
#       1 ax = plt.axes(projection=ccrs.Orthographic(135, -35))
# ----> 2 vod.isel(time=0).plot(ax=ax, transform=ccrs.PlateCarree());
#       3 ax.set_global(); ax.coastlines();
#
# ~/anaconda3/envs/sci/lib/python3.7/site-packages/xarray/plot/dataset_plot.py in __call__(self, *args, **kwargs)
#     160     def __call__(self, *args, **kwargs):
#     161         raise ValueError(
# --> 162             "Dataset.plot cannot be called directly. Use "
#     163             "an explicit plot method, e.g. ds.plot.scatter(...)"
#     164         )
#
# ValueError: Dataset.plot cannot be called directly. Use an explicit plot method, e.g. ds.plot.scatter(...)

# %%
 p = vod.isel(time=[0, 4]).plot(transform=ccrs.PlateCarree(), col='time',
                                subplot_kws={'projection': ccrs.Orthographic(140, -35)})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-7b63330ada3e> in <module>
#       1 p = vod.isel(time=[0, 4]).plot(transform=ccrs.PlateCarree(), col='time',
# ----> 2                                subplot_kws={'projection': ccrs.Orthographic(140, -35)})
#
# ~/anaconda3/envs/sci/lib/python3.7/site-packages/xarray/plot/dataset_plot.py in __call__(self, *args, **kwargs)
#     160     def __call__(self, *args, **kwargs):
#     161         raise ValueError(
# --> 162             "Dataset.plot cannot be called directly. Use "
#     163             "an explicit plot method, e.g. ds.plot.scatter(...)"
#     164         )
#
# ValueError: Dataset.plot cannot be called directly. Use an explicit plot method, e.g. ds.plot.scatter(...)

# %%
plt.imshow(vod.vod_day[50,:,:], 
           cmap='viridis')
