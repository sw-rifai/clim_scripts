# %%
import rasterio
from matplotlib import pyplot as plt

# %%
dataset = rasterio.open("../../data_general/MYD11A2_C6_LST/MYD11A2_C6_LST_1km_SEAUS_2002_2019-0000001792-0000003584.tif")

# %%
dataset.xy
# Out:
# <bound method TransformMethodsMixin.xy of <open DatasetReader name='../../data_general/MYD11A2_C6_LST/MYD11A2_C6_LST_1km_SEAUS_2002_2019-0000001792-0000003584.tif' mode='r'>>

# %%
dataset.name
# Out:
# '../../data_general/MYD11A2_C6_LST/MYD11A2_C6_LST_1km_SEAUS_2002_2019-0000001792-0000003584.tif'

# %%
dataset.mode
# Out:
# 'r'

# %%
dataset.width
# Out:
# 1559

# %%
dataset.height
# Out:
# 1792

# %%
band1 = dataset.read(2)

# %%
band1
# Out:
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]])

# %%
plt.imshow(band1, cmap='pink')

# %%
from rasterio.plot import show_hist
show_hist(band1, bins=50)
# Out:
# /home/sami/miniconda3/envs/sci/lib/python3.7/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/sami/miniconda3/envs/sci/lib/python3.7/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
from rasterio.plot import show

# %%
show(band1, transform=dataset.transform)

# %%
import numpy as np
import xarray as xr
import holoviews as hv
from holoviews import opts
import geoviews as gv
import datashader as ds
import cartopy.crs as ccrs

from holoviews.operation.datashader import regrid, shade
from bokeh.tile_providers import STAMEN_TONER

hv.extension('bokeh', width=80)
# Out:
# WARNING:param.notebook_extension: Holoviews bokeh extension could not be imported, it raised the following exception: ModuleNotFoundError('No module named 'bokeh.plotting.helpers'')
# WARNING:param.notebook_extension: bokeh backend hook <function _load_bokeh at 0x7fb891987440> failed with following exception: No module named 'bokeh.plotting.helpers'
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-20-cb288d72d08e> in <module>
#      10 from bokeh.tile_providers import STAMEN_TONER
#      11
# ---> 12 hv.extension('bokeh', width=80)
#
# ~/miniconda3/envs/sci/lib/python3.7/site-packages/param/parameterized.py in __new__(class_, *args, **params)
#    2810         inst = class_.instance()
#    2811         inst.param._set_name(class_.__name__)
# -> 2812         return inst.__call__(*args,**params)
#    2813
#    2814     def __call__(self,*args,**kw):
#
# ...
